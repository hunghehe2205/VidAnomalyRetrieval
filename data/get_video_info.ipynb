# %%
import cv2

video_path = "/Users/hunghehe2205/Projects/VAD/Capstone/video/Stealing077_x264.mp4"

cap = cv2.VideoCapture(video_path)

# Lấy FPS
fps = cap.get(cv2.CAP_PROP_FPS)

# Lấy tổng số frame
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

print("FPS:", fps)
print("Total frames:", frame_count)

cap.release()
# Out:
# FPS: 30.0
# Total frames: 19185

# %%
# 16 video dropped từ filtered
DROPPED_VIDEOS = {
    "Fighting041_x264", "Shoplifting014_x264", "Stealing077_x264"
}
